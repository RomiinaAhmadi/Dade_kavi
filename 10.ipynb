# %% [markdown]
# سوال 10
#
# رکوردهای تکراری را شناسایی کنید.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
selected_df = df[['age', 'cp', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal','target']]

print(selected_df.duplicated().sum())
print(selected_df[df.duplicated()])
# Out:
# 1
#      age  cp  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 164   38   2    0        1      173      0      0.0      2   4     2       1

# %% [markdown]
# در صورت ادغام دو دیتا بیس یا ثبت شدن دوباره ی رکوردی میتوان داده ی تکراری داشت
# فقط یک داده ی تکراری داریم
